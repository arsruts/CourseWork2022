# %%
import pandas as pd

# %%
data = pd.read_csv('final_res.csv')
data
# Out:
#      Unnamed: 0                                               Name  \
# 0             0  Новая концепция для музея «Микула» в Нижнем Но...
# 1             1  Развитие туристического кластера в Кроноцком з...
# 2             2  Создание мобильного приложения СППР для диагно...
# 3             3                       Гуманитарная политика России
# 4             4         Подкаст про современное высшее образование
# ..          ...                                                ...
# 411         411  Веб-приложение для генерации страницы-каталога...
# 412         412  Распознавание и визуализация распространения л...
# 413         413  Приложение-маркетплейс для продажи и обмена вещей
# 414         414                                     Free TON DeBot
# 415         415  Приложение-маркетплейс для продажи и обмена вещей
#
#               Id                                             Campus  \
# 0    596292031.0  ['Москва', 'Санкт-Петербург', 'Нижний Новгород...
# ...

# %%
data = data.drop(['Unnamed: 0', 'Link'], axis=1)
data
# Out:
#                                                   Name           Id  \
# 0    Новая концепция для музея «Микула» в Нижнем Но...  596292031.0
# 1    Развитие туристического кластера в Кроноцком з...  596294035.0
# 2    Создание мобильного приложения СППР для диагно...  599269634.0
# 3                         Гуманитарная политика России  594287546.0
# 4           Подкаст про современное высшее образование  603090884.0
# ..                                                 ...          ...
# 411  Веб-приложение для генерации страницы-каталога...          NaN
# 412  Распознавание и визуализация распространения л...          NaN
# 413  Приложение-маркетплейс для продажи и обмена вещей          NaN
# 414                                     Free TON DeBot          NaN
# 415  Приложение-маркетплейс для продажи и обмена вещей          NaN
#
#                                                 Campus  \
# 0    ['Москва', 'Санкт-Петербург', 'Нижний Новгород...
# ...

# %%
for i in range(0,45):
    data['Supervisor'][i] = data['Supervisor'][i][2:-2]
    
data
# Out:
# <ipython-input-4-32d958710f39>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Supervisor'][i] = data['Supervisor'][i][2:-2]
#                                                   Name           Id  \
# 0    Новая концепция для музея «Микула» в Нижнем Но...  596292031.0
# 1    Развитие туристического кластера в Кроноцком з...  596294035.0
# 2    Создание мобильного приложения СППР для диагно...  599269634.0
# 3                         Гуманитарная политика России  594287546.0
# 4           Подкаст про современное высшее образование  603090884.0
# ..                                                 ...          ...
# 411  Веб-приложение для генерации страницы-каталога...          NaN
# 412  Распознавание и визуализация распространения л...          NaN
# ...

# %%
for i in range(45,416):
    if data['Number of vacancies on the project'][i] == 'Индивидуальный':
        data['Number of vacancies on the project'][i] = 2
    else:
        data['Number of vacancies on the project'][i] = 10

data
# Out:
# <ipython-input-5-9b388a432bc0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Number of vacancies on the project'][i] = 2
# <ipython-input-5-9b388a432bc0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Number of vacancies on the project'][i] = 10
#                                                   Name           Id  \
# 0    Новая концепция для музея «Микула» в Нижнем Но...  596292031.0
# 1    Развитие туристического кластера в Кроноцком з...  596294035.0
# 2    Создание мобильного приложения СППР для диагно...  599269634.0
# ...

# %%
data.to_csv('final_res_edited.xls')
